# %% [markdown]
# # Link Prediction for Historical Texts
#
# The following notebook contains the example code for running Link Prediction on historical texts, using Wikidata for predictions.
#
# Keep in mind that this code assumes you have performed a Named Entity Recognition on the texts, storing both the identified entities and the tokens from the text in a JSON format. You may see an example [here](https://github.com/ExarcaFidalgo/linkpredictionforhistoricaltexts/blob/master/Medieval%20NER%20with%20Roberta.ipynb).
#
#
#
# ---
#
# Firstly, we install the required dependencies.

# %%
# !pip install python-Levenshtein --quiet
# !pip install SPARQLWrapper --quiet
# !pip install unidecode --quiet

import pandas as pd
import Levenshtein as lev
from unidecode import unidecode
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 13.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 11.0 MB/s eta 0:00:00

# %% [markdown]
# We use a KGT5 model trained on the WikiKG90MV2 dataset, a Knowledge Graph extracted from Wikidata. Considering that a Wikidata triple has the form *(?head, ?relation, ?tail)*, this model predicts the *?tail* entity given *?head* and *?relation*.

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
tokenizer = AutoTokenizer.from_pretrained("apoorvumang/kgt5-wikikg90mv2")
model = AutoModelForSeq2SeqLM.from_pretrained("apoorvumang/kgt5-wikikg90mv2")
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.86k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/242M [00:00<?, ?B/s]

# %% [markdown]
# The following is the code provided in https://huggingface.co/apoorvumang/kgt5-wikikg90mv2 for performing the prediction.

# %%
import torch

def getScores(ids, scores, pad_token_id):
    """get sequence scores from model.generate output"""
    scores = torch.stack(scores, dim=1)
    log_probs = torch.log_softmax(scores, dim=2)
    # remove start token
    ids = ids[:,1:]
    # gather needed probs
    x = ids.unsqueeze(-1).expand(log_probs.shape)
    needed_logits = torch.gather(log_probs, 2, x)
    final_logits = needed_logits[:, :, 0]
    padded_mask = (ids == pad_token_id)
    final_logits[padded_mask] = 0
    final_scores = final_logits.sum(dim=-1)
    return final_scores.cpu().detach().numpy()

def topkSample(input, model, tokenizer,
                num_samples=5,
                num_beams=1,
                max_output_length=30):
    tokenized = tokenizer(input, return_tensors="pt")
    out = model.generate(**tokenized,
                        do_sample=True,
                        num_return_sequences = num_samples,
                        num_beams = num_beams,
                        eos_token_id = tokenizer.eos_token_id,
                        pad_token_id = tokenizer.pad_token_id,
                        output_scores = True,
                        return_dict_in_generate=True,
                        max_length=max_output_length,)
    out_tokens = out.sequences
    out_str = tokenizer.batch_decode(out_tokens, skip_special_tokens=True)
    out_scores = getScores(out_tokens, out.scores, tokenizer.pad_token_id)

    pair_list = [(x[0], x[1]) for x in zip(out_str, out_scores)]
    sorted_pair_list = sorted(pair_list, key=lambda x:x[1], reverse=True)
    return sorted_pair_list

def greedyPredict(input, model, tokenizer):
    input_ids = tokenizer([input], return_tensors="pt").input_ids
    out_tokens = model.generate(input_ids)
    out_str = tokenizer.batch_decode(out_tokens, skip_special_tokens=True)
    return out_str[0]

# %% [markdown]
# Importing Google Drive for loading the necessary files. The example files are available [here](https://github.com/ExarcaFidalgo/linkpredictionforhistoricaltexts/tree/master/data).

# %%
import json
from google.colab import drive
drive.mount('/content/drive')

# Change the working directory to the project folder
# %cd "/content/drive/MyDrive/LinkPrediction"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/LinkPrediction

# %% [markdown]
# One of the problems with this particular model is that it expects entity labels both as input and output; since we need the exact entity ID for later queries, we need to search for the corresponding ID for each label predicted.
#
# In order to avoid overbearing the Wikidata endpoint, a cache is provided with all the names and surnames available in Wikidata at June of 2024.
#
# As we'll see later, any new label-ID mapping that we obtain will be cached as well in a separate file as to reduce the number of queries.

# %%
gndf = pd.read_csv("./given_names.csv", index_col=0)
fndf = pd.read_csv("./family_names.csv", index_col=0)

# %%
gndf
# Out:
#                                              item    itemLabel
# 0       http://www.wikidata.org/entity/Q101445895        Bride
# 1       http://www.wikidata.org/entity/Q101445892       Gönenç
# 2       http://www.wikidata.org/entity/Q101445675  Cairistiona
# 3       http://www.wikidata.org/entity/Q101445664      Veronia
# 4       http://www.wikidata.org/entity/Q101445647     Tremayne
# ...                                           ...          ...
# 113438  http://www.wikidata.org/entity/L746117-S1   L746117-S1
# 113439  http://www.wikidata.org/entity/L746186-S1   L746186-S1
# 113440  http://www.wikidata.org/entity/L746882-S1   L746882-S1
# 113441  http://www.wikidata.org/entity/L746885-S1   L746885-S1
# 113442  http://www.wikidata.org/entity/L746902-S1   L746902-S1
#
# [113443 rows x 2 columns]

# %%
fndf
# Out:
#                                              item    itemLabel
# 0       http://www.wikidata.org/entity/Q100273204      Amorisa
# 1       http://www.wikidata.org/entity/Q100273203      Amorena
# 2       http://www.wikidata.org/entity/Q100273202      Amirati
# 3       http://www.wikidata.org/entity/Q100273201  Aminashvili
# 4       http://www.wikidata.org/entity/Q100273200      Amigleo
# ...                                           ...          ...
# 645319     http://www.wikidata.org/entity/L500927      L500927
# 645320     http://www.wikidata.org/entity/L501199      L501199
# 645321     http://www.wikidata.org/entity/L580511      L580511
# 645322     http://www.wikidata.org/entity/L585200      L585200
# 645323     http://www.wikidata.org/entity/L585393      L585393
#
# [645324 rows x 2 columns]

# %% [markdown]
# The function *search_name* looks for a given name (or surname) in the previous cache, up to a Levenshtein distance of 2. So, if we search "Fernándiz" and there are no matches, it will match the entity "Fernándiz" with a Levensthein distance of 1.

# %%
from functools import lru_cache

def search_name_distance(name, distance, df):
    return df.loc[df['itemLabel'].str.contains(name, na=False)]

@lru_cache(maxsize=None)
def search_name(name, typ):
    print(f"Searching for {name} in Name Cache")
    distance = 0
    results = pd.DataFrame({"item": []})
    while len(results) == 0 and distance < 3:
        if typ == "given name":
            results = search_name_distance(name, distance, gndf)
        else:
            results = search_name_distance(name, distance, fndf)
        if len(results) > 0:
            break
        distance += 1
    return results["item"].to_list()

# %% [markdown]
# The subsequent section is adapted from the Wikidata Query Service code provided for querying in Python. *get_results* performs a query to the Wikidata endpoint, while *search_item* queries to check if there's any item with a certain label and which has as class/subclass a certain item.

# %%
import sys
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"


def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()


def search_item(label, superclass):
  if superclass == "Literal":
    return [{"item": {"value": "Literal"}}]
  print(f"Running query with label {label} and superclass {superclass}")
  query = "SELECT DISTINCT ?item ?itemLabel WHERE { "
  query += f"?item rdfs:label \"{label}\"@en ."
  query += f"?item wdt:P31/wdt:P279* wd:{superclass} ."
  query += "SERVICE wikibase:label { bd:serviceParam wikibase:language \"[AUTO_LANGUAGE],en,da,es,fr,jp,nl,no,ru,sv,zh\". } }"
  results = get_results(endpoint_url, query)
  return results["results"]["bindings"]

# %% [markdown]
# This dictionary is derived from the Wikidata Entity Schema for class Human [(E10)](https://www.wikidata.org/wiki/EntitySchema:E10). For each property in the schema, we create a tuple where its first element is the label on the property and the second element is the superclass of the property value. I.e., *father* has as superclass of its possible value *human* (Q5).

# %%
entity_schema_map = {
    "Q5": [
    ("gender", "Q48277"),
    ("place of birth", "Q56061"),
    ("place of death", "Q56061"),
    ("date of birth", "Literal"),
    ("date of death", "Literal"),
    ("given name", "Q202444"),
    ("family name", "Q101352"),
    ("occupation", "Q12737077"),
    ("name in native language", "Literal"),
    ("country of citizenship", "Q56061"),
    ("father", "Q5"),
    ("mother", "Q5"),
    ("sibling", "Q5"),
    ("spouse", "Q5"),
    ("children", "Q5"),
    ("relatives", "Q5"),
    ("native language", "Q34770"),
    ("languages spoken, written or signed", "Q34770"),
    ("writing language", "Q34770"),
    ],
   "Q56061": [
   ]
}

# %% [markdown]
# A few collections for storing relevant data.
#
#
# *   *Id_map* stores additional information for a given entity ID (at document level)
# *   *Label_map* stores the WID (or candidate WIDs) for a given label.
# *   *Entities* stores all the entities found in the NER phase.
# *   *Tokens* stores all the tokens in the document which we applied the NER on.
#
# We store *label_map* in a file for efficiency in future tasks.

# %%
id_map = {}
label_map = {} # Label cache
tokens = {}
entities = {}

try:
  with open("/content/drive/MyDrive/LinkPrediction/output/label_id.json", 'r', encoding="utf8") as f:
    print("\nLoading label_id map from previous iterations...")
    label_map = json.load(f)
    print(f"Loaded label_id map of length {len(label_map.keys())}")
except:
  print("Cache file does not exist.")
# Out:
# Loading label_id map from previous iterations...
# Loaded label_id map of length 283

# %% [markdown]
# Simple function for showing the properties in an entity in a smooth way.

# %%
def show_properties(props):
  output = "\n"
  output += "\n//////////////////////////"
  output += f"\nEntity: {props['head']}"
  output += "\nList of properties:"
  output += f"\n\tInstance of: {props['instance of']}"
  for p in props:
    if p not in ["head", "instance of", "id"]:
      output += f"\n\t{p}: {props[p]['label']} ({props[p]['item']})"
  return output

# %% [markdown]
# If no match was found for tail entity for certain properties, we could suggest that a new entity may be required in Wikidata.
#
# For example, given an entity "Suer Pérez", if no *given name* was predicted, a new *male given name* entity labelled "Suer" may be lacking in Wikidata.
#
# We specify both the property and the class of the entity which enables this check.

# %%
def check_lacking_entities(ent):
  messages = []
  properties = [("given name", "http://www.wikidata.org/entity/Q5"), ("family name", "http://www.wikidata.org/entity/Q5")]
  for p in properties:
    if ent['instance of'] != p[1]:
      continue
    if " " not in ent['head']: #Alfonso, Iohan... (single names)
      messages.append(f"\nA new entity may be required for ({ent['head']}, given name / family name, ?tail). No match found for tail entity.")
      continue
    if p[0] not in ent.keys():
      messages.append(f"\nA new entity may be required for ({ent['head']}, {p}, ?tail). No match found for tail entity.")
  return messages

# %% [markdown]
# # Semi-inductive prediction
#
# In the first phase of the link prediction, we will perform a semi-inductive prediction, that is, we will consider NER entities as unseen nodes of the Wikidata Knowledge Graph and predict relationships with the unseen node as head and existing nodes as tails.
#
# The process is as follows:
#
# 1.   Take every entity in the *entities* collection, populated with the results of the NER process. (*sep_entities* function)
# 2.   For each entity and property in the entity schema, perform a prediction with the KGT5-WikiKG90MV2 model. (*semi_inductive_prediction* function)
#
# Hence, if we have a "Miguel Álvarez" entity of type PERSON as an output of NER, we'd do predictions such as *Miguel Álvarez | gender* which -in this case- will predict the tail [*male*](https://www.wikidata.org/wiki/Q6581097).
#
# Given the peculiarities of the model, the remaining code in *semi_inductive_prediction* is dedicated to obtaining the WID which would match the predicted tail label.
#
# Note that the *instance_of* property is not predicted, but obtained through the NER process, and from that information we choose the adequate entity schema for the entity.

# %%
predictions = 0

@lru_cache(maxsize=None)
def get_label_id(cache_key):
    item = label_map.get(cache_key)
    if item is None:
        return None
    print(f"Loading from label_id cache: {cache_key}")
    return item

def semi_inductive_prediction(head, typ, id):
  properties = {}
  properties["id"] = id
  properties["head"] = head
  properties["instance of"] = f"http://www.wikidata.org/entity/{typ}"
  es_properties = entity_schema_map[typ]

  fragments = head.split()
  unidecoded_head = unidecode(head)

  for prop in es_properties:
    input = unidecoded_head + " | " + prop[0]
    out = topkSample(input, model, tokenizer, num_samples=5)
    best = out[0]
    label = best[0]
    sclass = prop[1]
    item = None
    found_in_cache = False

    if prop[0] == "given name": # They should always have a given name in this context
      cache_key = f"{label}-{sclass}"
      item = label_map.get(cache_key)
      if item is None:
          curated_label = label.split(":")[0]
          item = search_name(curated_label, prop[0])
          print(item)
          if item:
              label_map[cache_key] = item
              properties[prop[0]] = {"label": label, "item": item}
              found_in_cache = True
      else:
          properties[prop[0]] = {"label": label, "item": item}
          found_in_cache = True
      continue

    if best[1] > -0.5:
      # Retrieving accentuated character if any
      for fragment in fragments:
        if lev.distance(fragment, label) <= 1:
          label = fragment

      cache_key = f"{label}-{sclass}"
      item = label_map.get(cache_key)

      if item is None:
        if prop[0] == "family name":
          curated_label = label.split(":")[0] #Suáriz: family name
          item = search_name(curated_label, prop[0])
          if item:
            label_map[cache_key] = item
            found_in_cache = True

        if not found_in_cache:
          results = search_item(label, sclass)
          if not results:
            item = "No Wikidata Entity was detected for this label and superclass. Please check manually."
          elif len(results) == 1:
            item = results[0]["item"]["value"]
            label_map[cache_key] = item
          else:
            item = [result["item"]["value"] for result in results]
            label_map[cache_key] = item
      else:
        item = get_label_id(cache_key)

      properties[prop[0]] = {"label": label, "item": item}
  return properties

# %%
import copy

def sep_entities(entities):
  unique_results = {}
  results = []
  for ent in entities:
    name = ent[0]
    typ = ent[1]
    id = ent[2]
    if name in unique_results.keys():
      same_result = unique_results[name].copy()
      same_result["id"] = id
      results.append(same_result)
    else:
      res = semi_inductive_prediction(name, typ, id)
      results.append(res)
      unique_results[name] = res
  return results

def showResults(results):
  output = ""
  for res in results:
    output += show_properties(res)
  return output

# %% [markdown]
# Now we apply all those functions. We load the NER data from a file (change at will) and populate *id_map*, *tokens* and *entities*.

# %%
import json

with open("/content/drive/MyDrive/LinkPrediction/output/ner.json", 'r', encoding="utf8") as f:
  print("\nProcessing NER file...")
  data = json.load(f)
  for file_name in data:
    tokens[file_name] = data[file_name]["tokens"]
    entities[file_name] = []
    for ent in data[file_name]["entities"]:
      typ = ""
      name = ent["name"]
      if ent["label"] == "PERS":
        typ = "Q5"
      elif ent["label"] == "LOC":
        typ = "Q56061"
      id = len(id_map.keys()) + 1
      id_map[id] = {"start": ent["start"], "end": ent["end"], "sent": ent["sent"]}
      entities[file_name].append([name, typ, id])

print(len(entities))
print(entities)
# Out:
# Processing NER file...
# 129
# {'output_BIO_AMSPO_FSV_1552.txt': [['Diego Suáriz', 'Q5', 1], ['Santiago d’Arllós', 'Q56061', 2], ['Lanera', 'Q56061', 3], ['Alffonso Fernández', 'Q5', 4], ['Oviedo', 'Q56061', 5], ['Portal', 'Q56061', 6], ['María Álvariz', 'Q5', 7], ['Borondés', 'Q56061', 8], ['San Miguel de Váscones', 'Q56061', 9], ['Losa de Traspinnera', 'Q56061', 10], ['Pero Fernándiz', 'Q5', 11], ['Pero Sardina', 'Q5', 12], ['Sancha Fernándiz', 'Q5', 13], ['Marinna Suáriz', 'Q5', 14], ['Fernando', 'Q5', 15], ['Oviedo', 'Q56061', 16], ['Fernán Iohanniz de Piqueros', 'Q5', 17], ['Piqueros', 'Q56061', 18], ['Pero Pérez de Villameana', 'Q5', 19], ['Villameana', 'Q56061', 20], ['Diego Suáriz', 'Q5', 21], ['Andreo Martíniz', 'Q5', 22], ['Oviedo', 'Q56061', 23]], 'output_BIO_AMSPO_FSV_1377.txt': [['Menén Suáriz', 'Q5', 24], ['Borondés', 'Q56061', 25], ['Loriença Suáriz', 'Q5', 26], ['Alffonso Fernándiz', 'Q5', 27], ['Oviedo', 'Q56061', 28], ['Aldonça Suáriz', 'Q5', 29], ['Menén Suáriz', 'Q5', 30], ['María Álvariz', 'Q5', 31], ['Suer Pérez', 'Q5', 32], ['María Yánnez', 'Q5', 33], ['Menén Suáriz', 'Q5', 34], ['Aldonça Suáriz', 'Q5', 35], ['Borondés', 'Q56061', 36], ['Vallongo', 'Q56061', 37], ['Grado', 'Q56061', 38], ['Aldonça Suáriz', 'Q5', 39], ['Iohan Gonçáliz', 'Q5', 40], ['Gonçalo Suáriz', 'Q5', 41], ['María Álvariz', 'Q5', 42], ['Fernando', 'Q5', 43], ['Suer Díaz de Cortina', 'Q5', 44], ['Cortina', 'Q56061', 45], ['Garçía Suáriz', 'Q5', 46], ['Suer Díaz', 'Q5', 47], ['Menén Suáriz', 'Q5', 48], ['Loriença Suáriz', 'Q5', 49], ['Suer Díaz', 'Q5', 50], ['Alffonso Fernándiz', 'Q5', 51], ['Alffonso Fernándiz', 'Q5', 52], ['Fernán Fernándiz', 'Q5', 53], ['Gonçalo Rodríguiz', 'Q5', 54], ['Rodrigo Martíniz', 'Q5', 55], ['Fernán Sirgo de Vallo', 'Q5', 56], ['Vallo', 'Q56061', 57], ['Suer Rodríguiz', 'Q5', 58], ['Fernán Garot', 'Q5', 59], ['Alffonso Pérez de San Romano', 'Q5', 60], ['San Romano', 'Q56061', 61], ['Suer Rodríguiz', 'Q5', 62], ['Pero Fernándiz', 'Q5', 63], ['Grado', 'Q56061', 64], ['Pero Fernándiz', 'Q5', 65]], 'output_BIO_AMSPO_FSV_1553.txt': [['Diego Fernándiz', 'Q5', 66], ['Ingnés Gonçáliz', 'Q5', 67], ['Perdones', 'Q56061', 68], ['Gozón', 'Q56061', 69], ['Alffonso Fernándiz', 'Q5', 70], ['María Álvarez', 'Q5', 71], ['Oviedo', 'Q56061', 72], ['San Miguel de Váscones', 'Q56061', 73], ['Vanlongo', 'Q56061', 74], ['Grado', 'Q56061', 75], ['Fernando', 'Q5', 76], ['Alffonso', 'Q5', 77], ['Castiella', 'Q56061', 78], ['León', 'Q56061', 79], ['Odo', 'Q5', 80], ['Oviedo', 'Q56061', 81], ['Gonçalo Bernaldo', 'Q5', 82], ['Alffonso Martíniz', 'Q5', 83], ['Ruy Nicolás', 'Q5', 84], ['Martin Sánchez', 'Q5', 85], ['Iohan Fernándiz de Oviedo', 'Q5', 86], ['Oviedo', 'Q56061', 87], ['Alvar Rodríguiz', 'Q5', 88], ['Abillés', 'Q56061', 89]], 'output_BIO_AMSPO_FSV_1355.txt': [['Pero Suáriz de Borondés', 'Q5', 90], ['Borondés', 'Q56061', 91], ['Suer Rodríguiz', 'Q5', 92], ['Alffonso Ferrándiz', 'Q5', 93], ['María Áluarez', 'Q5', 94], ['Ouiedo', 'Q56061', 95], ['Borondés', 'Q56061', 96], ['Traspinnera', 'Q56061', 97], ['Nozedo', 'Q56061', 98], ['Suer Alffonso', 'Q5', 99], ['Pero Díaz de Uega', 'Q5', 100], ['Uega', 'Q56061', 101], ['Alffonso', 'Q5', 102], ['Alffonso Áluariz', 'Q5', 103], ['Diego Suáriz de Uega', 'Q5', 104], ['Uega', 'Q56061', 105], ['Alffonso Pérez', 'Q5', 106], ['Alffonso Pérez de Luarca', 'Q5', 107], ['Luarca', 'Q56061', 108], ['Aluar Pérez', 'Q5', 109], ['Diego Martíniz', 'Q5', 110], ['Ouiedo', 'Q56061', 111]], 'output_BIO_AMSPO_FSV_1350.txt': [['Fernán Pérez', 'Q5', 112], ['Fernán Blanco', 'Q5', 113], ['Borondés', 'Q56061', 114], ['San Miguel de Váscones', 'Q56061', 115], ['Grado', 'Q56061', 116], ['Alffonso Fernándiz', 'Q5', 117], ['Oviedo al Portal', 'Q56061', 118], ['Borondés', 'Q56061', 119], ['Heros', 'Q56061', 120], ['Sienrra', 'Q56061', 121], ['Lavazes', 'Q56061', 122], ['Heros', 'Q56061', 123], ['Goçona', 'Q5', 124], ['Grado', 'Q56061', 125], ['Alvar Suáriz', 'Q5', 126], ['Grado', 'Q56061', 127], ['Cueva', 'Q56061', 128], ['Suer Rodríguiz de Borond ...

# %% [markdown]
# We perform a semi-inductive prediction for each **unique** entity on the list. If the predicted tail label is available at the cache for the relevant class, it will load. Either way, it will do a query with *search_name*.
#
# *(In the example output, most of the results are available at the cache; the execution will speed up as the files are processed).*
#
# We first store the results for the SIP for each file and join them later.

# %%
for file in entities:
  print("\nProcessing " + file + "...")
  file_entities = entities[file]
  file_results = sep_entities(file_entities)
  with open(f"/content/drive/MyDrive/LinkPrediction/output/sip/{file}.json", 'w', encoding='utf-8') as f:
    json.dump(file_results, f, indent=4, ensure_ascii=False)

with open('/content/drive/MyDrive/LinkPrediction/output/label_id.json', 'w', encoding='utf-8') as output_file:
  json.dump(label_map, output_file, indent=4, ensure_ascii=False)
# Out:
# Processing output_BIO_AMSPO_FSV_1552.txt...
# Loading from label_id cache: male-Q48277
# Loading from label_id cache: Suáriz-Q101352
# Loading from label_id cache: Spanish-Literal
# Loading from label_id cache: Spanish-Q34770
# Loading from label_id cache: Fernández-Q101352
# Loading from label_id cache: female-Q48277
# Loading from label_id cache: Álvariz-Q101352
# Loading from label_id cache: Fernándiz-Q101352
# Loading from label_id cache: Spain-Q56061
# Loading from label_id cache: Sardina-Q101352
# Loading from label_id cache: Italian-Q34770
# Loading from label_id cache: Portuguese-Literal
# Loading from label_id cache: Portuguese-Q34770
# Loading from label_id cache: Brazil-Q56061
# Loading from label_id cache: Pérez-Q101352
# Loading from label_id cache: Martíniz-Q101352
#
# Processing output_BIO_AMSPO_FSV_1377.txt...
# Loading from label_id cache: Turkish-Q34770
# Loading from label_id cache: Yánnez-Q101352
# Loading from label_id cache: Goncaliz-Q101352
# Loading from label_id cache: Díaz-Q101352
# Loading from label_id cache: Rodríguiz-Q101352
# Loading from label_id cache: Garot-Q101352
# Loading from label_id cache: French-Literal
# Loading from label_id cache: French-Q34770
#
# Processing output_BIO_AMSPO_FSV_1553.txt...
# Loading from label_id cache: Álvarez-Q101352
# Loading from label_id cache: Bernaldo-Q101352
# Loading from label_id cache: Nicolas: family name-Q101352
# Loading from label_id cache: Sánchez-Q101352
#
# Processing output_BIO_AMSPO_FSV_1355.txt...
# Loading from label_id cache: Ferrándiz-Q101352
# Loading from label_id cache: Áluarez-Q101352
# Loading from label_id cache: Alffonso-Q101352
# Loading from label_id cache: Áluariz-Q101352
#
# Processing output_BIO_AMSPO_FSV_1350.txt...
# Loading from label_id cache: Blanco-Q101352
# Loading from label_id cache: Saco-Q101352
# Loading from label_id cache: Alfonso-Q101352
#
# Processing output_BIO_AMSPO_FSV_1540.txt...
#
# Processing output_BIO_AMSPO_FSV_1367.txt...
# Loading from label_id cache: Peláiz-Q101352
# Loading from label_id cache: Garcia-Q101352
#
# Processing output_BIO_AMSPO_FSV_1554.txt...
# Loading from label_id cache: Sánchiz-Q101352
# Loading from label_id cache: Suárez-Q101352
# Loading from label_id cache: Vidal-Q101352
# Loading from label_id cache: Iohanniz-Q101352
#
# Processing output_BIO_AMSPO_FSV_1577.txt...
# Loading from label_id cache: Rodríguez-Q101352
# Loading from label_id cache: France-Q56061
# Loading from label_id cache: Iohan-Q101352
# Loading from label_id cache: Finnish-Literal
# Loading from label_id cache: Martino: family name-Q101352
#
# Processing output_BIO_AMSPO_FSV_1555.txt...
# Loading from label_id cache: Yannez-Q101352
# Loading from label_id cache: Duraniz-Q101352
# Loading from label_id cache: Iohaniz-Q101352
# Loading from label_id cache: Michel: family name-Q101352
#
# Processing output_BIO_AMSPO_FSP_306.txt...
# Loading from label_id cache: Peláez-Q101352
#
# Processing output_BIO_AMSPO_FSV_1551.txt...
# Searching for Ordónniz in Name Cache
# Running query with label Ordónniz and superclass Q101352
# Loading from label_id cache: Turkish-Literal
# Loading from label_id cache: Turkey-Q56061
#
# Processing output_BIO_AMSPO_FSV_1564.txt...
# Loading from label_id cache: Gutiérriz-Q101352
# Loading from label_id cache: Martínez-Q101352
#
# Processing output_BIO_AMSPO_FSV_1567.txt...
# Loading from label_id cache: Gutérriz-Q101352
#
# Processing output_BIO_AMSPO_FSV_1572.txt...
# Loading from label_id cache: Chirildos-Q101352
#
# Processing output_BIO_AMSPO_FSV_1565.txt...
# Loading from label_id cache: Apparicio-Q101352
# Loading from label_id cache: Ancient Greek-Q34770
# Loading from label_id cache: Martinus: family name-Q101352
# Loading from label_id cache: Latin-Q34770
#
# Processing output_BIO_AMSPO_FSV_1580.txt...
# Loading from label_id cache: Gómez-Q101352
#
# Processing output_BIO_AMSPO_FSV_1576.txt...
#
# Processing output_BIO_AMSPO_FSV_1578.txt...
# Loading from label_id cache: Cherildos-Q101352
# Loading from label_id cache: del Rosal-Q101352
#
# Processing output_BIO_AMSPO_FSV_1561.txt...
# Loading from label_id cache: Alvarez-Q101352
#
# Processing output_BIO_AMSPO_FSV_1568.txt...
#
# Processing output_BIO_AMSPO_FSV_1558.txt...
# Loading from label_id cache: Gonzáliz-Q101352
#
# Processing output_BIO_AMSPO_FSV_1579.txt...
# Loading from label_id cache: Goncalez-Q101352
# Loading from label_id cache: González-Q101352
#
# Processing output_BIO_AMSPO_FSV_1566.txt...
#
# Processing output_BIO_AMSPO_FSV_1560.txt...
# Loading from label_id cache: Abaltzisketa-Q56061
# Loading from label_id cache: Abaltzisketa-Literal
#
# Processing output_BIO_AMSPO_FSV_1569.txt...
# Loading from label_id cache: Andreo-Q101352
#
# Processing output_BIO_AMSPO_FSV_1585.txt...
# Loading from label_id cache: Martiniz-Q101352
#
# Processing output_BIO_AMSPO_FSV_1574.txt...
# Loading from label_id cache: García-Q101352
# Loading from label_id cache: Per[ez-Q101352
#
# Processing output_BIO_AMSPO_FSV_1570.txt...
#
# Processing output_BIO_AMSPO_FSV_1559.txt...
# Loading from label_id cache: Fernandiz-Q101352
#
# Processing output_BIO_AMSPO_FSV_1563.txt...
# Loading from label_id cache: Yánniz-Q101352
# Loading from label_id cache: Russian-Q34770
#
# Processing output_BIO_AMSPO_FSV_1602.txt...
# Loading from label_id cache: Menendiz-Q101352
# Loading from label_id cache: Estéuanez-Q101352
#
# Processing output_BIO_AMSPO_FSV_1591b.txt...
# Loading from label_id cache: Yuannes-Q101352
# Loading from label_id cache: Cuerdo-Q101352
# Loading from label_id cache: Iohannez-Q101352
# Loading from label_id cache: Iohannes-Q101352
#
# Processing output_BIO_AMSPO_FSV_1589.txt...
# Loading from label_id cache: Martinez-Q101352
#
# Processing output_BIO_AMSPO_FSV_1603.txt...
# Loading from label_id cache: Italy-Q56061
#
# Processing output_BIO_AMSPO_FSV_1601.txt...
# Loading from label_id cache: Menéndiz-Q101352
# Loading from label_id cache: Menéndez-Q101352
#
# Processing output_BIO_AMSPO_FSV_1599.txt...
# Loading from label_id cache: Tomas: family name-Q101352
#
# Processing output_BIO_AMSPO_FSV_1588.txt...
# Loading from label_id cache: Morán-Q101352
#
# Processing output_BIO_AMSPO_FSV_1587.txt...
# Searching for Suer in Name Cache
# ['http://www.wikidata.org/entity/Q36151970']
# Loading from label_id cache: Abril-Q101352
# Loading from label_id cache: Pico-Q101352
# Loading from label_id cache: Nariz-Q101352
#
# Processing output_BIO_AMSPO_FSV_1583.txt...
# Loading from label_id cache: Iohánniz-Q101352
#
# Processing output_BIO_AMSPO_FSV_1581.txt...
#
# Processing output_BIO_AMSPO_FSV_1598.txt...
# Loading from label_id cache: Gonçalez-Q101352
# Loading from label_id cache: Alffonsso-Q101352
#
# Processing output_BIO_AMSPO_FSV_1582.txt...
# Searching for Emilio in Name Cache
# ['http://www.wikidata.org/entity/Q100783466', 'http://www.wikidata.org/entity/Q123759034', 'http://www.wikidata.org/entity/Q5371795', 'http://www.wikidata.org/entity/Q55083918', 'http://www.wikidata.org/entity/Q65767303', 'http://www.wikidata.org/entity/Q73221684', 'http://www.wikidata.org/entity/Q97582349']
#
# Processing output_BIO_AMSPO_FSV_1596.txt...
#
# Processing output_BIO_AMSPO_FSV_1593.txt...
# Loading from label_id cache: Alías-Q101352
#
# Processing output_BIO_AMSPO_FSV_1594.txt...
#
# Processing output_BIO_AMSPO_FSV_1590.txt...
#
# Processing output_BIO_AMSPO_FSV_1595.txt...
#
# Processing output_BIO_AMSPO_FSV_1591.txt...
# Loading from label_id cache: Pacho-Q101352
# Loading from label_id cache: Laganna-Q101352
#
# Processing output_BIO_AMSPO_FSV_1600.txt...
#
# Processing output_BIO_AMSPO_FSV_1597.txt...
#
# Processing output_BIO_AMSPO_FSV_1584.txt...
#
# Processing output_BIO_AMSPO_FSV_1586.txt...
#
# Processing output_BIO_AMSPO_FSV_1620.txt...
# Searching for Mara in Name Cache
# ['http://www.wikidata.org/entity/Q101427605', 'http://www.wikidata.org/entity/Q100904760', 'http://www.wikidata.org/entity/Q102046223', 'http://www.wikidata.org/entity/Q106481870', 'http://www.wikidata.org/entity/Q108824283', 'http://www.wikidata.org/entity/Q116366980', 'http://www.wikidata.org/entity/Q116687881', 'http://www.wikidata.org/entity/Q122215499', 'http://www.wikidata.org/entity/Q12716730', 'http://www.wikidata.org/entity/Q1528582', 'http://www.wikidata.org/entity/Q16278940', 'http://www.wikidata.org/entity/Q165054', 'http://www.wikidata.org/entity/Q20000565', 'http://www.wikidata.org/entity/Q20000606', 'http://www.wikidata.org/entity/Q20523885', 'http://www.wikidata.org/entity/Q21145192', 'http://www.wikidata.org/entity/Q3845281', 'http://www.wikidata.org/entity/Q54819791', 'http://www.wikidata.org/entity/Q59847743', 'http://www.wikidata.org/entity/Q67524300', 'http://www.wikidata.org/entity/Q86663671', 'http://www.wikidata.org/entity/Q87049857', 'http://www.wikidata.org/entity/Q96650726', 'http://www.wikidata.org/entity/Q96651839', 'http://www.wikidata.org/entity/Q96653577', 'http://www.wikidata.org/entity/Q96653578', 'http://www.wikidata.org/entity/Q96675398', 'http://www.wikidata.org/entity/Q96675399', 'http://www.wikidata.org/entity/Q96675400']
#
# Processing output_BIO_AMSPO_FSV_1592.txt...
# Loading from label_id cache: Estévanez-Q101352
# Searching for Iohánnez in Name Cache
# Running query with label Iohánnez and superclass Q101352
#
# Processing output_BIO_AMSPO_FSV_1605.txt...
# Loading from label_id cache: Ferrándoz-Q101352
#
# Processing output_BIO_AMSPO_FSV_1625.txt...
# Loading from label_id cache: Uerán-Q101352
#
# Processing output_BIO_AMSPO_FSV_1618.txt...
#
# Processing output_BIO_AMSPO_FSV_1624.txt...
#
# Processing output_BIO_AMSPO_FSV_1628.txt...
# Loading from label_id cache: Rodriguiz-Q101352
# Searching for Iohanus in Name Cache
# []
#
# Processing output_BIO_AMSPO_FSV_1619.txt...
# Loading from label_id cache: Morina-Q101352
# Loading from label_id cache: Marcos: family name-Q101352
# Loading from label_id cache: Nieto-Q101352
#
# Processing output_BIO_AMSPO_FSV_1617.txt...
# Loading from label_id cache: Franco: family name-Q101352
#
# Processing output_BIO_AMSPO_FSV_1614.txt...
#
# Processing output_BIO_AMSPO_FSV_1632.txt...
#
# Processing output_BIO_AMSPO_FSV_1609.txt...
#
# Processing output_BIO_AMSPO_FSV_1629.txt...
# Loading from label_id cache: Ponz-Q101352
#
# Processing output_BIO_AMSPO_FSV_1622.txt...
# Loading from label_id cache: Anes-Q101352
# Loading from label_id cache: Swedish-Q34770
#
# Processing output_BIO_AMSPO_FSV_1630.txt...
#
# Processing output_BIO_AMSPO_FSV_1608.txt...
# Loading from label_id cache: Picón-Q101352
# Loading from label_id cache: Gato-Q101352
#
# Processing output_BIO_AMSPO_FSV_1613.txt...
# Loading from label_id cache: Périz-Q101352
# Loading from label_id cache: Peláyz-Q101352
# Loading from label_id cache: Escantola-Q101352
#
# Processing output_BIO_AMSPO_FSV_1612.txt...
# Loading from label_id cache: Tebera-Q101352
#
# Processing output_BIO_AMSPO_FSV_1621.txt...
# Loading from label_id cache: Guillez-Q101352
#
# Processing output_BIO_AMSPO_FSV_1610.txt...
#
# Processing output_BIO_AMSPO_FSV_1627.txt...
# Loading from label_id cache: Prieto-Q101352
#
# Processing output_BIO_AMSPO_FSV_1631.txt...
# Loading from label_id cache: Girálliz-Q101352
# Loading from label_id cache: Santiago: family name-Q101352
#
# Processing output_BIO_AMSPO_FSV_1649.txt...
# Loading from label_id cache: Moro-Q101352
#
# Processing output_BIO_AMSPO_FSV_1673.txt...
#
# Processing output_BIO_AMSPO_FSV_1650.txt...
# Loading from label_id cache: Romanian-Literal
# Loading from label_id cache: Romania-Q56061
# Loading from label_id cache: Romanian-Q34770
#
# Processing output_BIO_AMSPO_FSV_1657.txt...
#
# Processing output_BIO_AMSPO_FSV_1638.txt...
# Loading from label_id cache: Cabeça-Q101352
# Loading from label_id cache: Tebiera-Q101352
#
# Processing output_BIO_AMSPO_FSV_1653.txt...
# Loading from label_id cache: Perez-Q101352
#
# Processing output_BIO_AMSPO_FSV_1644.txt...
# Loading from label_id cache: Lana: family name-Q101352
#
# Processing output_BIO_AMSPO_FSV_1663.txt...
# Loading from label_id cache: Gorrión-Q101352
#
# Processing output_BIO_AMSPO_FSV_1664.txt...
# Loading from label_id cache: Carrión-Q101352
# Loading from label_id cache: Pisón-Q101352
#
# Processing output_BIO_AMSPO_FSV_1677.txt...
#
# Processing output_BIO_AMSPO_FSV_1660.txt...
#
# Processing output_BIO_AMSPO_FSV_1672.txt...
#
# Processing output_BIO_AMSPO_FSV_1642.txt...
#
# Processing output_BIO_AMSPO_FSV_1661.txt...
#
# Processing output_BIO_AMSPO_FSV_1675.txt...
#
# Processing output_BIO_AMSPO_FSV_1654.txt...
#
# Processing output_BIO_AMSPO_FSV_1647.txt...
#
# Processing output_BIO_AMSPO_FSV_1640.txt...
#
# Processing output_BIO_AMSPO_FSV_1636.txt...
#
# Processing output_BIO_AMSPO_FSV_1651.txt...
#
# Processing output_BIO_AMSPO_FSV_1635.txt...
#
# Processing output_BIO_AMSPO_FSV_1639.txt...
#
# Processing output_BIO_AMSPO_FSV_1656.txt...
#
# Processing output_BIO_AMSPO_FSV_1646.txt...
# Loading from label_id cache: Díez-Q101352
# Loading from label_id cache: Salamanes-Q101352
#
# Processing output_BIO_AMSPO_FSV_1697.txt...
# Loading from label_id cache: Gutiérrez-Q101352
# Loading from label_id cache: Paris-Literal
#
# Processing output_BIO_AMSPO_FSV_1695.txt...
# Loading from label_id cache: Ferrández-Q101352
#
# Processing output_BIO_AMSPO_FSV_1686.txt...
# Searching for de las Quintanes in Name Cache
# Running query with label de las Quintanes and superclass Q101352
#
# Processing output_BIO_AMSPO_FSV_1694.txt...
#
# Processing output_BIO_AMSPO_FSV_1680b.txt...
#
# Processing output_BIO_AMSPO_FSV_1690.txt...
#
# Processing output_BIO_AMSPO_FSV_1683.txt...
# Loading from label_id cache: Domínguiz-Q101352
# Loading from label_id cache: Seco-Q101352
#
# Processing output_BIO_AMSPO_FSV_1682.txt...
# Loading from label_id cache: Corcoua-Q101352
#
# Processing output_BIO_AMSPO_FSV_1692.txt...
# Loading from label_id cache: Menén-Q101352
#
# Processing output_BIO_AMSPO_FSV_1738.txt...
#
# Processing output_BIO_AMSPO_FSV_1687.txt...
#
# Processing output_BIO_AMSPO_FSV_1687b.txt...
# Searching for Henry in Name Cache
# ['http://www.wikidata.org/entity/Q107301238', 'http://www.wikidata.org/entity/Q107304918', 'http://www.wikidata.org/entity/Q113679037', 'http://www.wikidata.org/entity/Q113855738', 'http://www.wikidata.org/entity/Q115472485', 'http://www.wikidata.org/entity/Q115750123', 'http://www.wikidata.org/entity/Q1158477', 'http://www.wikidata.org/entity/Q117812741', 'http://www.wikidata.org/entity/Q117748017', 'http://www.wikidata.org/entity/Q125908963', 'http://www.wikidata.org/entity/Q13584864', 'http://www.wikidata.org/entity/Q19688577', 'http://www.wikidata.org/entity/Q20087943', 'http://www.wikidata.org/entity/Q29640882', 'http://www.wikidata.org/entity/Q5722070', 'http://www.wikidata.org/entity/Q57656280', 'http://www.wikidata.org/entity/Q58174697', 'http://www.wikidata.org/entity/Q58211706', 'http://www.wikidata.org/entity/Q58211846', 'http://www.wikidata.org/entity/Q58211940', 'http://www.wikidata.org/entity/Q59772019', 'http://www.wikidata.org/entity/Q59773272', 'http://www.wikidata.org/entity/Q60556737', 'http://www.wikidata.org/entity/Q60589333', 'http://www.wikidata.org/entity/Q60613447', 'http://www.wikidata.org/entity/Q65177180', 'http://www.wikidata.org/entity/Q65177209', 'http://www.wikidata.org/entity/Q65177211', 'http://www.wikidata.org/entity/Q65177229', 'http://www.wikidata.org/entity/Q65767386', 'http://www.wikidata.org/entity/Q65767387', 'http://www.wikidata.org/entity/Q66554545', 'http://www.wikidata.org/entity/Q67123985', 'http://www.wikidata.org/entity/Q67604337', 'http://www.wikidata.org/entity/Q67606796', 'http://www.wikidata.org/entity/Q67606893', 'http://www.wikidata.org/entity/Q72217055', 'http://www.wikidata.org/entity/Q72819191', 'http://www.wikidata.org/entity/Q96122919', 'http://www.wikidata.org/entity/Q96655847', 'http://www.wikidata.org/entity/Q98204984', 'http://www.wikidata.org/entity/Q98456535', 'http://www.wikidata.org/entity/Q98817842', 'http://www.wikidata.org/entity/Q98861420']
# Loading from label_id cache: Uasallo-Q101352
#
# Processing output_BIO_AMSPO_FSV_1684.txt...
# Loading from label_id cache: Toro-Q101352
#
# Processing output_BIO_AMSPO_FSV_1678.txt...
#
# Processing output_BIO_AMSPO_FSV_1685.txt...
# Loading from label_id cache: Vassallo-Q101352
# Loading from label_id cache: Finland-Q56061
#
# Processing output_BIO_AMSPO_FSV_1680.txt...
#
# Processing output_BIO_AMSPO_FSV_1679.txt...
# Loading from label_id cache: de Toro-Q101352
#
# Processing output_BIO_AMSPO_FSV_1809.txt...
#
# Processing output_BIO_AMSPO_FSV_1691.txt...
#
# Processing output_BIO_AMSPO_FSV_1681.txt...
#
# Processing output_BIO_AMSPO_FSV_1722.txt...
# Loading from label_id cache: Yanes-Q101352
# Loading from label_id cache: Sanchéz-Q101352
#
# Processing output_BIO_AMSPO_FSV_1735.txt...
#
# Processing output_BIO_AMSPO_FSV_1731.txt...
#
# Processing output_BIO_AMSPO_FSV_1607.txt...
#
# Processing output_BIO_AMSPO_FSV_1615.txt...
#
# Processing output_BIO_AMSPO_FSV_1652.txt...
#
# Processing output_BIO_AMSPO_FSV_1648.txt...
#
# Processing output_BIO_AMSPO_FSV_1688.txt...
#
# Processing output_BIO_AMSPO_FSV_1696.txt...
# Loading from label_id cache: Garçia-Q101352
#
# Processing output_BIO_AMSPO_FSV_1730.txt...
# Loading from label_id cache: Sanctiago-Q101352
# Loading from label_id cache: Estevan-Q101352

# %%
import os

si_results = {}

output = ""
for filename in os.listdir("/content/drive/MyDrive/LinkPrediction/output/sip"):
    print("\nProcessing " + filename + "...")
    with open(f"/content/drive/MyDrive/LinkPrediction/output/sip/{filename}", 'r', encoding="utf8") as f:
      output += f"\n Predictions for {filename}\n"
      data = json.load(f)
      si_results[filename.split(".")[0]] = data
      output += showResults(data)
# Out:
# Processing output_BIO_AMSPO_FSV_1552.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1377.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1553.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1355.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1350.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1540.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1367.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1554.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1577.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1555.txt.json...
#
# Processing output_BIO_AMSPO_FSP_306.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1551.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1564.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1567.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1572.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1565.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1580.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1576.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1578.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1561.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1568.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1579.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1566.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1560.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1569.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1585.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1574.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1570.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1559.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1563.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1602.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1591b.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1589.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1603.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1601.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1599.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1588.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1587.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1583.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1581.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1598.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1582.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1596.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1593.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1594.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1590.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1595.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1591.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1600.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1597.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1584.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1586.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1620.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1592.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1605.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1625.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1618.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1624.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1628.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1619.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1617.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1614.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1632.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1609.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1629.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1622.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1630.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1608.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1613.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1612.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1621.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1610.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1627.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1631.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1649.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1673.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1650.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1657.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1638.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1653.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1644.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1663.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1664.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1677.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1660.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1672.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1642.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1661.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1675.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1654.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1647.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1640.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1636.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1651.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1635.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1639.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1656.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1646.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1697.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1695.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1686.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1694.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1680b.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1690.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1683.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1682.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1692.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1738.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1687.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1687b.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1684.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1678.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1685.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1680.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1679.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1809.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1691.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1681.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1722.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1735.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1731.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1607.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1615.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1652.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1648.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1688.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1696.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1730.txt.json...
#
# Processing output_BIO_AMSPO_FSV_1558.txt.json...

# %%
with open('/content/drive/MyDrive/LinkPrediction/output/sip.txt', 'w', encoding='utf-8') as f:
  f.write(output)

with open('/content/drive/MyDrive/LinkPrediction/output/sip.json', 'w', encoding='utf-8') as f:
  json.dump(si_results, f, ensure_ascii=False)

# %% [markdown]
# # Fully Inductive Prediction
#
# Now, with the information acquired in the previous phase, we will try and perform a fully inductive prediction; that is, to infer relationships exclusively between the NER entities.
#
# For that purpose, hereunder we explore the possibility of using Wikidata property paths to both describe and explore relationships between certain entities.
#
# The format is as follows: for each relevant property, the *queries* dictionary defines a CONSTRUCT query which will return a triplet if the described path does exist between the entities provided in the *restrictions* field.
#
# *(Notice that the properties align with the ones described in the Entity Schema which had as class of the property value one of the possible classes of the entities detected in NER; in this case, Q5).*
#
# For example, for the property *father* *(:e1 :father :e2)*, we check two possibilities:
# 1.   Both surname entities are equal and the name of *e2* is an instance of *male given name*.
# 2.   The surname of *e1* is a patronymic of the name of *e2*; that is, the surname of *e1* is an instance of *patronymic family name* which has as a qualifier *of* and the value of the latter is the name of *e2*.
#
# If any of those match, we infer that a relation of type father is **possible** between those two entities.

# %%
queries = {
    "father/children^": {
        "bidirectional": False,
        "restrictions": {"1": ["family name"], "2": ["given name"]},
        "query": """prefix : <http://example.org/>

                  CONSTRUCT {
                    # ?surname1 :connectedByPropertyPath ?name2 .
                  }
                  WHERE {
                        {
                        # ?surname1 wdt:P460 ?surname2 .
                        # ?surname2 p:P31 ?ps .
                        # ?ps ps:P31 wd:Q11455398.
                        # ?ps pq:P642 ?name2 .
                        VALUES ?surname1 {[[1_family name]]}
                        VALUES ?name2 {[[2_given name]]}
                        }
                        UNION
                        {
                        # ?surname1 p:P31 ?ps .
                        # ?ps ps:P31 wd:Q11455398.
                        # ?ps pq:P642 ?name2 .
                        VALUES ?surname1 {[[1_family name]]}
                        VALUES ?name2 {[[2_given name]]}
                        }
                        UNION
                        {
                        # ?surname1 p:P31 ?ps .
                        # ?ps ps:P31 wd:Q11455398.
                        # ?ps pq:P642 ?name3 .
                        # ?name2 wdt:P460 ?name3 .
                        VALUES ?surname1 {[[1_family name]]}
                        VALUES ?name2 {[[2_given name]]}
                        }
                        UNION
                        {
                        # ?surname1 wdt:P460 ?surname2 .
                        # ?surname2 p:P31 ?ps .
                        # ?ps ps:P31 wd:Q11455398.
                        # ?ps pq:P642 ?name3 .
                        # ?name2 wdt:P460 ?name3 .
                        VALUES ?surname1 {[[1_family name]]}
                        VALUES ?name2 {[[2_given name]]}
                        }
                        UNION
                        {
                        # ?name2 wdt:P31 wd:Q12308941.
                        # ?name2 wdt:P1705 ?nlabel .
                        # ?surname1 wdt:P1705 ?slabel .
                        VALUES ?surname1 {[[1_family name]]}
                        VALUES ?name2 {[[2_given name]]}
                        FILTER (str(?nlabel) = str(?slabel))
                        }

                  }
                  """

    },
    "father/children^-1": {
        "bidirectional": False,
        "restrictions": {"1": ["family name"], "2": ["given name", "family name"]},
        "query": """prefix : <http://example.org/>

                  CONSTRUCT {
                    # ?surname1 :connectedByPropertyPath ?name2 .
                  }
                  WHERE {
                        # ?name2 wdt:P31 wd:Q12308941.
                        VALUES ?surname1 {[[1_family name]]}
                        VALUES ?name2 {[[2_given name]]}
                        VALUES ?surname2 {[[2_family name]]}
                        FILTER (?surname1 = ?surname2)
                  }"""

    },
    "sibling": {
        "bidirectional": True,
        "restrictions": {"1": ["family name"], "2": ["family name"]},
        "query": """prefix : <http://example.org/>

                  CONSTRUCT {
                    # ?surname1 :connectedByPropertyPath ?surname2 .
                  }
                  WHERE {
                      SELECT ?surname1 ?surname2
                      WHERE {
                        # ?surname1 wdt:P1705 ?s1label .
                        # ?surname2 wdt:P1705 ?s2label .
                        VALUES ?surname1 {[[1_family name]]}
                        VALUES ?surname2 {[[2_family name]]}
                        FILTER (?surname1 = ?surname2 || str(?s1label) = str(?s2label))
                      }
                  }"""
    },
    "spouse": {
        "bidirectional": False,
        "restrictions": {"1": ["given name", "family name"], "2": ["given name", "family name"]},
        "query": """prefix : <http://example.org/>

                  CONSTRUCT {
                    # ?name1 :connectedByPropertyPath ?name2 .
                  }
                  WHERE {
                      SELECT ?name1 ?name2
                      WHERE {
                        # ?name2 wdt:P31 wd:Q11879590.
                        # ?name1 wdt:P31 wd:Q12308941.
                        VALUES ?name1 {[[1_given name]]}
                        VALUES ?name2 {[[2_given name]]}
                      }
                  }"""
        }
}

# %% [markdown]
# Since all the possible combinations of entities in a text of medium/large size can be of excessive number, we apply the principle of **proximity** to those predictions.
#
# That is, we consider that the relevant relationships between two entities are more likely to take place between those which are close to each other in the text. For that purpose, we define a window of 15 tokens which any tuple must be in to perform the previously seen queries.

# %%
import re

possible_links = {}
count_links = {}

def populate_query_entity(query, e, index):
  new_query = query
  for p in e:
    if p == "id" or "item" not in e[p]:
      continue
    if isinstance(e[p]["item"], list):
      values = ""
      n_items = 0
      for item in e[p]["item"]:
        values += item.replace("http://www.wikidata.org/entity/", "wd:") + " "
        n_items += 1
        if n_items > 20:
          break
      new_query = new_query.replace(f"[[{index}_{p}]]", values)
    else:
      new_query = new_query.replace(f"[[{index}_{p}]]", e[p]["item"].replace("http://www.wikidata.org/entity/", "wd:"))
  return new_query

def populate_query(query, e1, e2):
  new_query = populate_query_entity(query, e1, 1)
  new_query = populate_query_entity(new_query, e2, 2)
  return new_query


def check_restrictions(res, e1, e2):
  for r in res["1"]:
    if r not in e1.keys():
      return False
    elif "No Wikidata Entity" in e1[r]["item"]:
      return False
  for r in res["2"]:
    if r not in e2.keys():
      return False
    elif not e2[r]["item"]:
      print(e2)
      return False
    elif "No Wikidata Entity" in e2[r]["item"]:
      return False
  return True


def search_tokens(end, start, st1, st2, file):
  distance = 0
  found_first = False
  for token in tokens[f"{file}.txt"]:
    if token[3] == st1 and (token[2] - end < 2): # Found first entity, start the count
      found_first = True
      continue
    if token[3] == st2 and token[1] == start:
      found_first = False # Found second entity, count stops
      break
    if found_first:
      distance += 1
  return distance


def check_proximity(e1, e2, file):
  e1s = e1["start"]
  e2s = e2["start"]
  e1e = e1["end"]
  e2e = e2["end"]
  e1st = e1["sent"]
  e2st = e2["sent"]
  if e1st < e2st or (e1st == e2st and e1e < e2s): # e1 ... e2
    return search_tokens(e1e, e2s, e1st, e2st, file)
  else: # e2 ... e1
    return search_tokens(e2e, e1s, e2st, e1st, file)


def get_instance_index(token, ent, file):
  text = ""
  for i in range(len(tokens[f"{file}.txt"])):
    tok = tokens[f"{file}.txt"][i]
    if tok[1] <= ent["end"] or tok[3] < ent["sent"]:
      text += tok[0] + " "
    else:
      text += tokens[f"{file}.txt"][i][0]
      break
  count = len(re.findall(r'\b' + re.escape(token) + r'\b(?!\s+de\b)', text))
  return count


def search_possible_link(file, query_name, e1, e2):
  for link in possible_links[file][query_name]:
    if link["e1"] == e1["head"] and link["e2"] == e2["head"] and link["rel"] == query_name:
      return link
  return False


def fully_inductive_prediction(e1, e2, file, repeated_links=True):
  for prop in queries.keys():
    if not check_restrictions(queries[prop]["restrictions"], e1, e2):
      break
    query_name = prop
    if query_name == "father/children^-1":
      query_name = "father/children^"

    distance = 0 # Metric of proximity
    e1ti = id_map[e1["id"]]
    e2ti = id_map[e2["id"]]
    distance = check_proximity(e1ti, e2ti, file)

    if distance < 15:
      query_1 = populate_query(queries[prop]["query"], e1, e2)
      results = get_results(endpoint_url, query_1)["results"]["bindings"]
      if len(results) > 0: # There is a path that connects them
        link = {
            "e1": e1['head'],
            "e2": e2['head'],
            "e1index": get_instance_index(e1['head'], e1ti, file),
            "e2index": get_instance_index(e2['head'], e2ti, file),
            "rel": query_name,
            "distance": distance,
            "sent": e1ti["sent"]
        }
        if not repeated_links:
          existing_link = search_possible_link(file, query_name, e1,e2)
          if existing_link:
            count_links[file][f"{e1['head']}-{query_name}-{e2['head']}"] = count_links[file][f"{e1['head']}-{query_name}-{e2['head']}"] + 1
            if link["distance"] < existing_link["distance"]:
              existing_link["distance"] = link["distance"]
        if repeated_links or not existing_link:
          possible_links[file][query_name].append(link)
          count_links[file][f"{e1['head']}-{query_name}-{e2['head']}"] = 1
          e1[query_name] = e2["head"]


def allMatches(lst):
    return[(el1, el2) for el1 in lst for el2 in lst if el1!=el2]


for file in si_results.keys():
  print("\nProcessing " + file + "...")
  possible_links[file] = {"father/children^": [], "sibling": [], "spouse": [] }
  count_links[file] = {}
  for pair in allMatches(si_results[file]):
    fully_inductive_prediction(pair[0], pair[1], file)
  for prop in possible_links[file].keys():
    for i in range(len(possible_links[file][prop])):
      link = possible_links[file][prop][i]
      link["count"] = count_links[file][f"{link['e1']}-{link['rel']}-{link['e2']}"]
# Out:
# Processing output_BIO_AMSPO_FSV_1552...
# /usr/local/lib/python3.10/dist-packages/SPARQLWrapper/Wrapper.py:794: RuntimeWarning: Sending Accept header '*/*' because unexpected returned format 'json' in a 'CONSTRUCT' SPARQL query form
#   warnings.warn(
# Processing output_BIO_AMSPO_FSV_1377...
#
# Processing output_BIO_AMSPO_FSV_1553...
#
# Processing output_BIO_AMSPO_FSV_1355...
#
# Processing output_BIO_AMSPO_FSV_1350...
#
# Processing output_BIO_AMSPO_FSV_1540...
#
# Processing output_BIO_AMSPO_FSV_1367...
#
# Processing output_BIO_AMSPO_FSV_1554...
#
# Processing output_BIO_AMSPO_FSV_1577...
#
# Processing output_BIO_AMSPO_FSV_1555...
#
# Processing output_BIO_AMSPO_FSP_306...
#
# Processing output_BIO_AMSPO_FSV_1551...
#
# Processing output_BIO_AMSPO_FSV_1564...
#
# Processing output_BIO_AMSPO_FSV_1567...
#
# Processing output_BIO_AMSPO_FSV_1572...
#
# Processing output_BIO_AMSPO_FSV_1565...
#
# Processing output_BIO_AMSPO_FSV_1580...
#
# Processing output_BIO_AMSPO_FSV_1576...
#
# Processing output_BIO_AMSPO_FSV_1578...
#
# Processing output_BIO_AMSPO_FSV_1561...
#
# Processing output_BIO_AMSPO_FSV_1568...
#
# Processing output_BIO_AMSPO_FSV_1579...
#
# Processing output_BIO_AMSPO_FSV_1566...
#
# Processing output_BIO_AMSPO_FSV_1560...
#
# Processing output_BIO_AMSPO_FSV_1569...
#
# Processing output_BIO_AMSPO_FSV_1585...
#
# Processing output_BIO_AMSPO_FSV_1574...
#
# Processing output_BIO_AMSPO_FSV_1570...
#
# Processing output_BIO_AMSPO_FSV_1559...
#
# Processing output_BIO_AMSPO_FSV_1563...
#
# Processing output_BIO_AMSPO_FSV_1602...
#
# Processing output_BIO_AMSPO_FSV_1591b...
#
# Processing output_BIO_AMSPO_FSV_1589...
#
# Processing output_BIO_AMSPO_FSV_1603...
#
# Processing output_BIO_AMSPO_FSV_1601...
#
# Processing output_BIO_AMSPO_FSV_1599...
#
# Processing output_BIO_AMSPO_FSV_1588...
#
# Processing output_BIO_AMSPO_FSV_1587...
#
# Processing output_BIO_AMSPO_FSV_1583...
#
# Processing output_BIO_AMSPO_FSV_1581...
#
# Processing output_BIO_AMSPO_FSV_1598...
#
# Processing output_BIO_AMSPO_FSV_1582...
#
# Processing output_BIO_AMSPO_FSV_1596...
#
# Processing output_BIO_AMSPO_FSV_1593...
#
# Processing output_BIO_AMSPO_FSV_1594...
#
# Processing output_BIO_AMSPO_FSV_1590...
#
# Processing output_BIO_AMSPO_FSV_1595...
#
# Processing output_BIO_AMSPO_FSV_1591...
#
# Processing output_BIO_AMSPO_FSV_1600...
#
# Processing output_BIO_AMSPO_FSV_1597...
#
# Processing output_BIO_AMSPO_FSV_1584...
#
# Processing output_BIO_AMSPO_FSV_1586...
#
# Processing output_BIO_AMSPO_FSV_1620...
#
# Processing output_BIO_AMSPO_FSV_1592...
#
# Processing output_BIO_AMSPO_FSV_1605...
#
# Processing output_BIO_AMSPO_FSV_1625...
#
# Processing output_BIO_AMSPO_FSV_1618...
#
# Processing output_BIO_AMSPO_FSV_1624...
#
# Processing output_BIO_AMSPO_FSV_1628...
#
# Processing output_BIO_AMSPO_FSV_1619...
#
# Processing output_BIO_AMSPO_FSV_1617...
#
# Processing output_BIO_AMSPO_FSV_1614...
#
# Processing output_BIO_AMSPO_FSV_1632...
#
# Processing output_BIO_AMSPO_FSV_1609...
#
# Processing output_BIO_AMSPO_FSV_1629...
#
# Processing output_BIO_AMSPO_FSV_1622...
#
# Processing output_BIO_AMSPO_FSV_1630...
#
# Processing output_BIO_AMSPO_FSV_1608...
#
# Processing output_BIO_AMSPO_FSV_1613...
#
# Processing output_BIO_AMSPO_FSV_1612...
#
# Processing output_BIO_AMSPO_FSV_1621...
#
# Processing output_BIO_AMSPO_FSV_1610...
#
# Processing output_BIO_AMSPO_FSV_1627...
#
# Processing output_BIO_AMSPO_FSV_1631...
#
# Processing output_BIO_AMSPO_FSV_1649...
#
# Processing output_BIO_AMSPO_FSV_1673...
#
# Processing output_BIO_AMSPO_FSV_1650...
#
# Processing output_BIO_AMSPO_FSV_1657...
#
# Processing output_BIO_AMSPO_FSV_1638...
#
# Processing output_BIO_AMSPO_FSV_1653...
#
# Processing output_BIO_AMSPO_FSV_1644...
#
# Processing output_BIO_AMSPO_FSV_1663...
#
# Processing output_BIO_AMSPO_FSV_1664...
#
# Processing output_BIO_AMSPO_FSV_1677...
#
# Processing output_BIO_AMSPO_FSV_1660...
#
# Processing output_BIO_AMSPO_FSV_1672...
#
# Processing output_BIO_AMSPO_FSV_1642...
#
# Processing output_BIO_AMSPO_FSV_1661...
#
# Processing output_BIO_AMSPO_FSV_1675...
#
# Processing output_BIO_AMSPO_FSV_1654...
#
# Processing output_BIO_AMSPO_FSV_1647...
#
# Processing output_BIO_AMSPO_FSV_1640...
#
# Processing output_BIO_AMSPO_FSV_1636...
#
# Processing output_BIO_AMSPO_FSV_1651...
#
# Processing output_BIO_AMSPO_FSV_1635...
#
# Processing output_BIO_AMSPO_FSV_1639...
#
# Processing output_BIO_AMSPO_FSV_1656...
#
# Processing output_BIO_AMSPO_FSV_1646...
#
# Processing output_BIO_AMSPO_FSV_1697...
#
# Processing output_BIO_AMSPO_FSV_1695...
#
# Processing output_BIO_AMSPO_FSV_1686...
#
# Processing output_BIO_AMSPO_FSV_1694...
#
# Processing output_BIO_AMSPO_FSV_1680b...
#
# Processing output_BIO_AMSPO_FSV_1690...
#
# Processing output_BIO_AMSPO_FSV_1683...
#
# Processing output_BIO_AMSPO_FSV_1682...
#
# Processing output_BIO_AMSPO_FSV_1692...
#
# Processing output_BIO_AMSPO_FSV_1738...
#
# Processing output_BIO_AMSPO_FSV_1687...
#
# Processing output_BIO_AMSPO_FSV_1687b...
#
# Processing output_BIO_AMSPO_FSV_1684...
#
# Processing output_BIO_AMSPO_FSV_1678...
#
# Processing output_BIO_AMSPO_FSV_1685...
#
# Processing output_BIO_AMSPO_FSV_1680...
#
# Processing output_BIO_AMSPO_FSV_1679...
#
# Processing output_BIO_AMSPO_FSV_1809...
#
# Processing output_BIO_AMSPO_FSV_1691...
#
# Processing output_BIO_AMSPO_FSV_1681...
#
# Processing output_BIO_AMSPO_FSV_1722...
#
# Processing output_BIO_AMSPO_FSV_1735...
#
# Processing output_BIO_AMSPO_FSV_1731...
#
# Processing output_BIO_AMSPO_FSV_1607...
#
# Processing output_BIO_AMSPO_FSV_1615...
#
# Processing output_BIO_AMSPO_FSV_1652...
#
# Processing output_BIO_AMSPO_FSV_1648...
#
# Processing output_BIO_AMSPO_FSV_1688...
#
# Processing output_BIO_AMSPO_FSV_1696...
#
# Processing output_BIO_AMSPO_FSV_1730...
#
# Processing output_BIO_AMSPO_FSV_1558...

# %%
output_links = possible_links

output = ""
for file in output_links.keys():
  output += f"\nFile {file}: \n"
  for p in output_links[file].keys():
    output += f"\n\nPossible links for {p}: \n"
    for rel in output_links[file][p]:
      output += f"\n {rel['e1']} [index {rel['e1index']}] - {rel['rel']} -> {rel['e2']} [index {rel['e2index']}] ({rel['count']})"

with open('/content/drive/MyDrive/LinkPrediction/output/fip_sent_lim.txt', 'w', encoding='utf-8') as f:
  f.write(output)

with open('/content/drive/MyDrive/LinkPrediction/output/fip_sent_lim.json', 'w', encoding='utf-8') as f:
  json.dump(output_links, f, ensure_ascii=False)

# %%
lacking = []
lacking_unique = {}

with open("/content/drive/MyDrive/LinkPrediction/output/sip.json", 'r', encoding="utf8") as f:
  si_results = json.load(f)
  for file in si_results.keys():
    for ent in si_results[file]:
      lacking.extend(check_lacking_entities(ent))

  for message in lacking:
    if message not in lacking_unique.keys():
      lacking_unique[message] = 1
    else:
      lacking_unique[message] = lacking_unique[message] + 1

  output = ""
  for key, value in lacking_unique.items():
    output += key + str(value)
  output += f"There is a total of {sum(lacking_unique.values())} suggestions."
  with open('/content/drive/MyDrive/LinkPrediction/output/lacking.txt', 'w', encoding='utf-8') as f:
    f.write(output)
  print(output)
# Out:
# A new entity may be required for (Fernando, given name / family name, ?tail). No match found for tail entity.74
# A new entity may be required for (Fernán Iohanniz de Piqueros, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Fernán Sirgo de Vallo, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Alffonso, given name / family name, ?tail). No match found for tail entity.90
# A new entity may be required for (Odo, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Goçona, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Suer Rodríguiz de Borondés, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.9
# A new entity may be required for (Alfonso, given name / family name, ?tail). No match found for tail entity.94
# A new entity may be required for (María de Soto, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (María Alffonso, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.3
# A new entity may be required for (Fernán Alfonso de la Rúa, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Alfonso Iohan, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.2
# A new entity may be required for (Sancha, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Garçía, given name / family name, ?tail). No match found for tail entity.4
# A new entity may be required for (Martino, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Pedro, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Gutier Alffonso de Labares, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Sancho, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Rodrigo, given name / family name, ?tail). No match found for tail entity.10
# A new entity may be required for (Iohan, given name / family name, ?tail). No match found for tail entity.26
# A new entity may be required for (Petrus, given name / family name, ?tail). No match found for tail entity.10
# A new entity may be required for (Iohannes, given name / family name, ?tail). No match found for tail entity.6
# A new entity may be required for (Martinus, given name / family name, ?tail). No match found for tail entity.8
# A new entity may be required for (Iohan Alffonso Murçia, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Pero Alffonso, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.8
# A new entity may be required for (Suer Garçía de Villardevello, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Oddo, given name / family name, ?tail). No match found for tail entity.4
# A new entity may be required for (Iohan Álvariz Osoyro, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Iohan Alffonso de la Fonte, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Iohannus, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Martinibus, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Pero, given name / family name, ?tail). No match found for tail entity.4
# A new entity may be required for (Cosmea Pérez del Mieres del Camino, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (María Pérez de Borondés de Iu, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.2
# A new entity may be required for (Pero Alfonso del Pienso, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (María Pérez de Borondes de Iu, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Suer, given name / family name, ?tail). No match found for tail entity.4
# A new entity may be required for (Gonçalo Garçía de Uega, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (María [Garçia] de Berzió, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (García, given name / family name, ?tail). No match found for tail entity.4
# A new entity may be required for (Pedro Bono, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Orraca, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Martín Iohannes de Villarmosén, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Pedro Iohan, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Pero Bono, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Fernán Blanco de Borondes de Iuso, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Diego Suáriz de Borondes de Suso, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Suer Rodríguiz del Portal, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Mayor, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Garçía de Berzió, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (María Pérez de Borondes de Iuso, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Pero Alfonso del Penso, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Fernán Garçía de Veyga, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.2
# A new entity may be required for (Suer Alfonso de Uega, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Eluira Garçía de Sobrepenna, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Fernán Garçía de Vega, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Gutier Alffonso de Nora, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Iohan Alvariz Osoyro, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Iohanus, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Iohan de Dios, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Iohan Iohánniz de Caçes, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Gonçalo, given name / family name, ?tail). No match found for tail entity.4
# A new entity may be required for (Fernán Alfonso de Trassantisso, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Alffonsso, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Pero Alffonsso, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Suer Alffonsso, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (María Iohan de Tene, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Fernán Garçía de Uega, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Ruy Seto, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Picón, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (María Franca, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Suer Alfonso de la Ferrería, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Pero de Vallo, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Fernán Iohan de Morenti, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Alfonso de Oliuares, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.3
# A new entity may be required for (Heros, given name / family name, ?tail). No match found for tail entity.6
# A new entity may be required for (Iohan Alfonso de Godos, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Gonçalo Rodríguiz de Trasona, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Martín Alffonso de Caçes, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Suer Sirgo, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Berçió, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Suer Alffonso de Veyga, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Suer Alfonso de Vega, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.2
# A new entity may be required for (Nicolao Iohannis de Roçes de Pando, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Gonçalo Garçía de Faro, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Iohan Nicolás de Mercado, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Iohan Alfonso de la Gasconna, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Guitón, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Fernán Garçía de Villandax, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Pero Canno, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Fernán Alffonso de la Rúa, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Alffonso Garçía de Ferreros, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Marinna, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Alffonso de Pennafrol, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Martín, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Gutier Bono, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Hedrado, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Diego Alfonso de Solaçogue, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Martin Iohan de la Nozeda, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Roy Garçía de Berzió, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Bartolomé, given name / family name, ?tail). No match found for tail entity.4
# A new entity may be required for (Pero Sirgo de Vega, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Alfonso de Olivares, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Suer Alfonso de Veyga, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Suer Martínez de Nores, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Diegáluariz, given name / family name, ?tail). No match found for tail entity.4
# A new entity may be required for (Suer Gonçáliz de Ruy Seco, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Diego Arias de Somiedo, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Gonçalo Garçía de Veyga, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Lope Gonçález de […], ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Fernán Alfonso de Castannedo, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Diego Alfonso de La Caridat, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Fernán Garçía de Valles, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Alffonso de Oliuares, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Per Áluariz de Fueyo, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Fernán Alfonso de Salzedo, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Fernán Alffonso de Ouiedo, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Gutier Alfonso de la Rua, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Pero Alfonso de Borondes, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Suero, given name / family name, ?tail). No match found for tail entity.4
# A new entity may be required for (Arias Garçía de Texedo, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Suer Alffonso de Uega, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Iohan de Latores, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Pero Sirgo, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Iohan del Quadro de Paderny, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Domingo Alffonso de Labares, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Cabellinos, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Iohan de Vega, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Álvaro, given name / family name, ?tail). No match found for tail entity.2
# A new entity may be required for (Gonçalo de Lugones, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1
# A new entity may be required for (Fernán Alfonso de Nalió, ('family name', 'http://www.wikidata.org/entity/Q5'), ?tail). No match found for tail entity.1There is a total of 516 suggestions.
